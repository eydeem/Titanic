# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msn

# %%
df = pd.read_csv("train.csv")

# %%
df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %%
msn.matrix(df)

# %%
sns.countplot(x = 'Survived', data = df, hue='Pclass')

# %%
sns.countplot(x = 'Survived', data = df, hue='Sex')

# %%
df['if_male'] = df['Sex'].apply(lambda x: 1 if x == 'male' else 0)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
def embarked_type(cos):
    if cos == 'S':
        return 1
    elif cos == 'C':
        return 2
    elif cos == 'Q':
        return 3
    else:
        return 0

# %%
df['Embarked_type'] = df['Embarked'].apply(lambda x: embarked_type(x))

# %%
# drugi sposob
# df['Embarked'].replace(['S','C','Q'], [1,2,3], inplace = True)

# %%
df[['Embarked_type', 'Embarked']].head(15)
# Out:
#     Embarked_type Embarked
# 0               1        S
# 1               2        C
# 2               1        S
# 3               1        S
# 4               1        S
# 5               3        Q
# 6               1        S
# 7               1        S
# 8               1        S
# 9               2        C
# 10              1        S
# 11              1        S
# 12              1        S
# 13              1        S
# 14              1        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  if_male  Embarked_type
# 0      0         A/5 21171   7.2500   NaN        S        1              1
# 1      0          PC 17599  71.2833   C85        C        0              2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0              1
# 3      0            113803  53.1000  C123        S        0              1
# 4      0            373450   8.0500   NaN        S        1              1

# %%
sns.boxplot(x = 'Survived', y = 'Fare', data = df)

# %%
df.corr()['Survived']
# Out:
# PassengerId     -0.005007
# Survived         1.000000
# Pclass          -0.338481
# Age             -0.077221
# SibSp           -0.035322
# Parch            0.081629
# Fare             0.257307
# if_male         -0.543351
# Embarked_type    0.101849
# Name: Survived, dtype: float64

# %%
df.drop('Sex', inplace = True, axis = 1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  if_male  Embarked_type
# 0         A/5 21171   7.2500   NaN        S        1              1
# 1          PC 17599  71.2833   C85        C        0              2
# 2  STON/O2. 3101282   7.9250   NaN        S        0              1
# 3            113803  53.1000  C123        S        0              1
# 4            373450   8.0500   NaN        S        1              1

# %%
new_df = df

# %%
df[['1memb','2memb']]=df['Name'].str.split(',',expand=True).apply(lambda x: x.str.strip())

# %%
df['prefix'] = [str(row.split(".")[0].split()[-1]) if row else None for row in df["2memb"]]

# %%
df['prefix'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Jonkheer      1
# Mme           1
# Capt          1
# Lady          1
# Sir           1
# Ms            1
# Countess      1
# Don           1
# Name: prefix, dtype: int64

# %%
df[df['prefix'] == 'Col']
# Out:
#      PassengerId  Survived  Pclass                                 Name   Age  \
# 647          648         1       1  Simonius-Blumer, Col. Oberst Alfons  56.0
# 694          695         0       1                      Weir, Col. John  60.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked  if_male  Embarked_type  \
# 647      0      0   13213  35.50   A26        C        1              2
# 694      0      0  113800  26.55   NaN        S        1              1
#
#                1memb               2memb prefix
# 647  Simonius-Blumer  Col. Oberst Alfons    Col
# 694             Weir           Col. John    Col

# %%
plt.figure(figsize = (14,8))
sns.countplot(x = 'Survived', data = df, hue = 'prefix')
plt.legend(loc='upper right')

# %%
df['prefix'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Jonkheer      1
# Mme           1
# Capt          1
# Lady          1
# Sir           1
# Ms            1
# Countess      1
# Don           1
# Name: prefix, dtype: int64

# %%
# stan cywily: Rev - wielebny, Mr -pan, Miss - panna, Mrs - mężatka, Ms - pani(nieznana), Mlle = Ms/Miss, Mme - Madame (Mrs), Master - niepełnoletni
# tytuł zawodowy: Dr - doktor,
# wojsko: Col - pułkownik, Major - major, Capt - kapitan, 
# szlachta (nobility): Don - członek rodziny królewskiej/szlachta/mafia (hehe), Sir - sir, Countess - Hrabina, Lady - lady, Jonkheer - szlachta

# %%
df['type_of_title'] = df['prefix'].replace(['Dr', 'Rev','Col', 'Major', 'Mlle', 
                                   'Mme', 'Don', 'Sir', 'Countess', 'Ms', 'Lady', 'Capt', 'Jonkheer'],'with_title')
df['type_of_title'] = df['type_of_title'].map({'with_title': 0,'Mr': 1, "Miss": 2, "Mrs": 3, "Master": 4})

# %%
df['type_of_title'].unique()
# Out:
# array([1, 3, 2, 4, 0], dtype=int64)

# %%
plt.figure(figsize = (14,6))
sns.countplot(x = 'type_of_title', data = df, hue = 'Survived')

# %%
df.corr()['Survived']
# Out:
# PassengerId     -0.005007
# Survived         1.000000
# Pclass          -0.338481
# Age             -0.077221
# SibSp           -0.035322
# Parch            0.081629
# Fare             0.257307
# if_male         -0.543351
# Embarked_type    0.101849
# type_of_title    0.451099
# Name: Survived, dtype: float64

# %%
df[df['prefix'] == 'Master']
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 50            51         0       3
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 78            79         1       2
# 125          126         1       3
# 159          160         0       3
# 164          165         0       3
# 165          166         1       3
# 171          172         0       3
# 176          177         0       3
# 182          183         0       3
# 183          184         1       2
# 193          194         1       2
# 261          262         1       3
# 278          279         0       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 386          387         0       3
# 407          408         1       2
# 445          446         1       1
# 480          481         0       3
# 489          490         1       3
# 549          550         1       2
# 709          710         1       3
# 751          752         1       3
# 755          756         1       2
# 787          788         0       3
# 788          789         1       3
# 802          803         1       1
# 803          804         1       3
# 819          820         0       3
# 824          825         0       3
# 827          828         1       2
# 831          832         1       2
# 850          851         0       3
# 869          870         1       3
#
#                                                   Name    Age  SibSp  Parch  \
# 7                       Palsson, Master. Gosta Leonard   2.00      3      1
# 16                                Rice, Master. Eugene   2.00      4      1
# 50                          Panula, Master. Juha Niilo   7.00      4      1
# 59                  Goodwin, Master. William Frederick  11.00      5      2
# 63                               Skoog, Master. Harald   4.00      3      2
# 65                            Moubarek, Master. Gerios    NaN      1      1
# 78                       Caldwell, Master. Alden Gates   0.83      0      2
# 125                       Nicola-Yarred, Master. Elias  12.00      1      0
# 159                         Sage, Master. Thomas Henry    NaN      8      2
# 164                       Panula, Master. Eino Viljami   1.00      4      1
# 165    Goldsmith, Master. Frank John William "Frankie"   9.00      0      2
# 171                               Rice, Master. Arthur   4.00      4      1
# 176                      Lefebre, Master. Henry Forbes    NaN      3      1
# 182              Asplund, Master. Clarence Gustaf Hugo   9.00      4      2
# 183                          Becker, Master. Richard F   1.00      2      1
# 193                         Navratil, Master. Michel M   3.00      1      1
# 261                  Asplund, Master. Edvin Rojj Felix   3.00      4      2
# 278                                 Rice, Master. Eric   7.00      4      1
# 305                     Allison, Master. Hudson Trevor   0.92      1      2
# 340                     Navratil, Master. Edmond Roger   2.00      1      1
# 348             Coutts, Master. William Loch "William"   3.00      1      1
# 386                    Goodwin, Master. Sidney Leonard   1.00      5      2
# 407                     Richards, Master. William Rowe   3.00      1      1
# 445                          Dodge, Master. Washington   4.00      0      2
# 480                     Goodwin, Master. Harold Victor   9.00      5      2
# 489              Coutts, Master. Eden Leslie "Neville"   9.00      1      1
# 549                     Davies, Master. John Morgan Jr   8.00      1      1
# 709  Moubarek, Master. Halim Gonios ("William George")    NaN      1      1
# 751                                Moor, Master. Meier   6.00      0      1
# 755                          Hamalainen, Master. Viljo   0.67      1      1
# 787                          Rice, Master. George Hugh   8.00      4      1
# 788                         Dean, Master. Bertram Vere   1.00      1      2
# 802                Carter, Master. William Thornton II  11.00      1      2
# 803                    Thomas, Master. Assad Alexander   0.42      0      1
# 819                       Skoog, Master. Karl Thorsten  10.00      3      2
# 824                       Panula, Master. Urho Abraham   2.00      4      1
# 827                              Mallet, Master. Andre   1.00      0      2
# 831                    Richards, Master. George Sibley   0.83      1      1
# 850            Andersson, Master. Sigvard Harald Elias   4.00      4      2
# 869                    Johnson, Master. Harold Theodor   4.00      1      1
#
#               Ticket      Fare    Cabin Embarked  if_male  Embarked_type  \
# 7             349909   21.0750      NaN        S        1              1
# 16            382652   29.1250      NaN        Q        1              3
# 50           3101295   39.6875      NaN        S        1              1
# 59           CA 2144   46.9000      NaN        S        1              1
# 63            347088   27.9000      NaN        S        1              1
# 65              2661   15.2458      NaN        C        1              2
# 78            248738   29.0000      NaN        S        1              1
# 125             2651   11.2417      NaN        C        1              2
# 159         CA. 2343   69.5500      NaN        S        1              1
# 164          3101295   39.6875      NaN        S        1              1
# 165           363291   20.5250      NaN        S        1              1
# 171           382652   29.1250      NaN        Q        1              3
# 176             4133   25.4667      NaN        S        1              1
# 182           347077   31.3875      NaN        S        1              1
# 183           230136   39.0000       F4        S        1              1
# 193           230080   26.0000       F2        S        1              1
# 261           347077   31.3875      NaN        S        1              1
# 278           382652   29.1250      NaN        Q        1              3
# 305           113781  151.5500  C22 C26        S        1              1
# 340           230080   26.0000       F2        S        1              1
# 348       C.A. 37671   15.9000      NaN        S        1              1
# 386          CA 2144   46.9000      NaN        S        1              1
# 407            29106   18.7500      NaN        S        1              1
# 445            33638   81.8583      A34        S        1              1
# 480          CA 2144   46.9000      NaN        S        1              1
# 489       C.A. 37671   15.9000      NaN        S        1              1
# 549       C.A. 33112   36.7500      NaN        S        1              1
# 709             2661   15.2458      NaN        C        1              2
# 751           392096   12.4750     E121        S        1              1
# 755           250649   14.5000      NaN        S        1              1
# 787           382652   29.1250      NaN        Q        1              3
# 788        C.A. 2315   20.5750      NaN        S        1              1
# 802           113760  120.0000  B96 B98        S        1              1
# 803             2625    8.5167      NaN        C        1              2
# 819           347088   27.9000      NaN        S        1              1
# 824          3101295   39.6875      NaN        S        1              1
# 827  S.C./PARIS 2079   37.0042      NaN        C        1              2
# 831            29106   18.7500      NaN        S        1              1
# 850           347082   31.2750      NaN        S        1              1
# 869           347742   11.1333      NaN        S        1              1
#
#              1memb                                    2memb  prefix  \
# 7          Palsson                    Master. Gosta Leonard  Master
# 16            Rice                           Master. Eugene  Master
# 50          Panula                       Master. Juha Niilo  Master
# 59         Goodwin                Master. William Frederick  Master
# 63           Skoog                           Master. Harald  Master
# 65        Moubarek                           Master. Gerios  Master
# 78        Caldwell                      Master. Alden Gates  Master
# 125  Nicola-Yarred                            Master. Elias  Master
# 159           Sage                     Master. Thomas Henry  Master
# 164         Panula                     Master. Eino Viljami  Master
# 165      Goldsmith     Master. Frank John William "Frankie"  Master
# 171           Rice                           Master. Arthur  Master
# 176        Lefebre                     Master. Henry Forbes  Master
# 182        Asplund             Master. Clarence Gustaf Hugo  Master
# 183         Becker                        Master. Richard F  Master
# 193       Navratil                         Master. Michel M  Master
# 261        Asplund                 Master. Edvin Rojj Felix  Master
# 278           Rice                             Master. Eric  Master
# 305        Allison                    Master. Hudson Trevor  Master
# 340       Navratil                     Master. Edmond Roger  Master
# 348         Coutts           Master. William Loch "William"  Master
# 386        Goodwin                   Master. Sidney Leonard  Master
# 407       Richards                     Master. William Rowe  Master
# 445          Dodge                       Master. Washington  Master
# 480        Goodwin                    Master. Harold Victor  Master
# 489         Coutts            Master. Eden Leslie "Neville"  Master
# 549         Davies                   Master. John Morgan Jr  Master
# 709       Moubarek  Master. Halim Gonios ("William George")  Master
# 751           Moor                            Master. Meier  Master
# 755     Hamalainen                            Master. Viljo  Master
# 787           Rice                      Master. George Hugh  Master
# 788           Dean                     Master. Bertram Vere  Master
# 802         Carter              Master. William Thornton II  Master
# 803         Thomas                  Master. Assad Alexander  Master
# 819          Skoog                    Master. Karl Thorsten  Master
# 824         Panula                     Master. Urho Abraham  Master
# 827         Mallet                            Master. Andre  Master
# 831       Richards                    Master. George Sibley  Master
# 850      Andersson             Master. Sigvard Harald Elias  Master
# 869        Johnson                   Master. Harold Theodor  Master
#
#      type_of_title
# 7                4
# 16               4
# 50               4
# 59               4
# 63               4
# 65               4
# 78               4
# 125              4
# 159              4
# 164              4
# 165              4
# 171              4
# 176              4
# 182              4
# 183              4
# 193              4
# 261              4
# 278              4
# 305              4
# 340              4
# 348              4
# 386              4
# 407              4
# 445              4
# 480              4
# 489              4
# 549              4
# 709              4
# 751              4
# 755              4
# 787              4
# 788              4
# 802              4
# 803              4
# 819              4
# 824              4
# 827              4
# 831              4
# 850              4
# 869              4

# %%
df['1memb'].value_counts()
# Out:
# Andersson    9
# Sage         7
# Goodwin      6
# Carter       6
# Skoog        6
#             ..
# Potter       1
# Rothes       1
# Ekstrom      1
# Cor          1
# Mitchell     1
# Name: 1memb, Length: 667, dtype: int64

# %%
df['size_family'] = df['1memb'].apply(lambda x: df['1memb'].value_counts()[x])

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'Survived', data = df, hue = 'size_family')
plt.legend(loc = 'upper right')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  if_male  Embarked_type  \
# 0         A/5 21171   7.2500   NaN        S        1              1
# 1          PC 17599  71.2833   C85        C        0              2
# 2  STON/O2. 3101282   7.9250   NaN        S        0              1
# 3            113803  53.1000  C123        S        0              1
# 4            373450   8.0500   NaN        S        1              1
#
#        1memb                                       2memb prefix  \
# 0     Braund                             Mr. Owen Harris     Mr
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)    Mrs
# 2  Heikkinen                                 Miss. Laina   Miss
# 3   Futrelle          Mrs. Jacques Heath (Lily May Peel)    Mrs
# 4      Allen                           Mr. William Henry     Mr
#
#    type_of_title  size_family
# 0              1            2
# 1              3            1
# 2              2            1
# 3              3            2
# 4              1            2

# %%
# zająć się Cabin i Ticket
# popatrzec na size_family - chyba sie nie przyda, ale może uda się z Name coś innego wyciągnąc -> fajnie by było ;)

# %%
df['New_cabin'] = df['Cabin'].astype(str).str[0]

# %%
df['New_cabin'].unique()
# Out:
# array(['0', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df['New_cabin'] = df['New_cabin'].map({'0': 0, 'C': 1, "E": 2, "G": 3, "D": 4, 'A': 5, "B": 6, "F": 7, "T": 8})

# %%
plt.figure(figsize = (15,6))
sns.countplot(x = 'New_cabin', data = df, hue = 'Survived')

# %%
df['null_cabin'] = df['Cabin'].apply(lambda x: 0 if x == 0 else 1)

# %%
df[['null_cabin', 'Cabin']].head(10)
# Out:
#    null_cabin Cabin
# 0           0     0
# 1           1   C85
# 2           0     0
# 3           1  C123
# 4           0     0
# 5           0     0
# 6           1   E46
# 7           0     0
# 8           0     0
# 9           0     0

# %%
df.corr()['Survived']
# Out:
# PassengerId     -0.005007
# Survived         1.000000
# Pclass          -0.338481
# Age             -0.077221
# SibSp           -0.035322
# Parch            0.081629
# Fare             0.257307
# if_male         -0.543351
# Embarked_type    0.101849
# type_of_title    0.451099
# size_family     -0.049188
# New_cabin        0.270310
# null_cabin       0.316912
# Name: Survived, dtype: float64

# %%
plt.figure(figsize = (15,6))
sns.countplot(x = 'null_cabin', data = df, hue = 'Survived')

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Age              177
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin              0
# Embarked           2
# if_male            0
# Embarked_type      0
# 1memb              0
# 2memb              0
# prefix             0
# type_of_title      0
# size_family        0
# New_cabin          0
# null_cabin         0
# dtype: int64

# %%
df[['size_family','Parch']]
# Out:
#      size_family  Parch
# 0              2      0
# 1              1      0
# 2              1      0
# 3              2      0
# 4              2      0
# ..           ...    ...
# 886            1      0
# 887            3      0
# 888            2      2
# 889            1      0
# 890            1      0
#
# [891 rows x 2 columns]

# %%
df.corr()['Survived']
# Out:
# PassengerId     -0.005007
# Survived         1.000000
# Pclass          -0.338481
# Age             -0.077221
# SibSp           -0.035322
# Parch            0.081629
# Fare             0.257307
# if_male         -0.543351
# Embarked_type    0.101849
# type_of_title    0.451099
# size_family     -0.049188
# New_cabin        0.270310
# null_cabin       0.316912
# Name: Survived, dtype: float64
